# %%
import requests
import pandas as pd

# %%
url = f"https://api.binance.com/api/v3/depth"
params = {
    "symbol": "SOLUSDT",
    "limit": 100
}

# %%
orderbook_data = requests.get(url, params=params).json()
orderbook_data
# Out:
# {'lastUpdateId': 25881212091,
#  'bids': [['155.15000000', '189.55600000'],
#   ['155.14000000', '87.36400000'],
#   ['155.13000000', '91.38700000'],
#   ['155.12000000', '60.26900000'],
#   ['155.11000000', '412.37500000'],
#   ['155.10000000', '345.66000000'],
#   ['155.09000000', '141.15900000'],
#   ['155.08000000', '304.95000000'],
#   ['155.07000000', '376.40400000'],
#   ['155.06000000', '1350.94700000'],
#   ['155.05000000', '681.39500000'],
#   ['155.04000000', '261.11300000'],
#   ['155.03000000', '60.24500000'],
#   ['155.02000000', '980.89800000'],
#   ['155.01000000', '2574.12400000'],
#   ['155.00000000', '4854.43700000'],
#   ['154.99000000', '1154.23900000'],
#   ['154.98000000', '252.63900000'],
#   ['154.97000000', '539.87700000'],
#   ['154.96000000', '1886.89500000'],
#   ['154.95000000', '102.40100000'],
#   ['154.94000000', '1690.92300000'],
#   ['154.93000000', '216.93100000'],
#   ['154.92000000', '96.21000000'],
#   ['154.91000000', '199.11400000'],
# ...
